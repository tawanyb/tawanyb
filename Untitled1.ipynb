# %% [markdown]
# <a href="https://colab.research.google.com/github/tawanyb/tawanyb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sidetable
# !pip install pandas-profiling==3.3.0

# %%
#imortando as bibliotecas conforme aprendizado na aula !
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import sidetable
import pandas_profiling
import missingno as msno
from ipywidgets import interact, widgets

from sklearn import datasets
from sklearn.preprocessing import scale, minmax_scale, power_transform
# Out:
# /usr/local/lib/python3.10/dist-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %%
#configuracao aprendida na aula pra escala de grafica !

# %%
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    rc={
        'figure.figsize': (12,8)
    }
)

# %%
def list_attributes(obj):
  """Lista atributos e funções de um objeto"""
  return [attr for attr in obj.__dir__() if not attr.startswith('_')]

# %%
# leitura do arquivo csv !
df = pd.read_csv('/content/Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213542 entries, 0 to 213541
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    213542 non-null  object
#  1   StockCode    213542 non-null  object
#  2   Description  212703 non-null  object
#  3   Quantity     213541 non-null  float64
#  4   InvoiceDate  213541 non-null  object
#  5   UnitPrice    213541 non-null  float64
#  6   CustomerID   152130 non-null  float64
#  7   Country      213541 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 13.0+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 213537    555545     21937              STRAWBERRY   PICNIC BAG       5.0
# 213538    555545     20717               STRAWBERRY SHOPPER BAG      10.0
# 213539    555545    85099F                 JUMBO BAG STRAWBERRY      10.0
# 213540    555545     22383                LUNCH BAG SUKI DESIGN      10.0
# 213541    555545     21931                                  JUM       NaN
#
# ...

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity       float64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2024-04-30 11:55:22.968251&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#indentificando nulos
df[df.isna().any(axis=1)]
null_count = df['CustomerID'].isna().sum()
print(null_count)
# Out:
# 61412

# %%
#dropna
df.dropna
# Out:
# <bound method DataFrame.dropna of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 213537    555545     21937              STRAWBERRY   PICNIC BAG       5.0
# 213538    555545     20717               STRAWBERRY SHOPPER BAG      10.0
# 213539    555545    85099F                 JUMBO BAG STRAWBERRY      10.0
# 213540    555545     22383                LUNCH BAG SUKI DESIGN      10.0
# 213541    555545     21931                                  JUM       NaN
#
# ...

# %%
#filtros
inul = df['UnitPrice'].isnull() <= 0
totalinul= (sum(inul))
print(totalinul)
del (totalinul)
df[df['UnitPrice'] > 0]
# Out:
# 213541
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 213536    555545     22411    JUMBO SHOPPER VINTAGE RED PAISLEY      10.0
# 213537    555545     21937              STRAWBERRY   PICNIC BAG       5.0
# 213538    555545     20717               STRAWBERRY SHOPPER BAG      10.0
# 213539    555545    85099F                 JUMBO BAG STRAWBERRY      10.0
# 213540    555545     22383                LUNCH BAG SUKI DESIGN      10.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
isnul= df['Quantity'].isnull() <= 0
totalisnul=( sum(isnul))
print(totalisnul)
del (totalisnul)
df[df['Quantity'] > 0]
# Out:
# 213541
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 213536    555545     22411    JUMBO SHOPPER VINTAGE RED PAISLEY      10.0
# 213537    555545     21937              STRAWBERRY   PICNIC BAG       5.0
# 213538    555545     20717               STRAWBERRY SHOPPER BAG      10.0
# 213539    555545    85099F                 JUMBO BAG STRAWBERRY      10.0
# 213540    555545     22383                LUNCH BAG SUKI DESIGN      10.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Identificar valores duplicados
df[df.duplicated(keep=False)]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 485       536409     22111    SCOTTIE DOG HOT WATER BOTTLE       1.0
# 489       536409     22866   HAND WARMER SCOTTY DOG DESIGN       1.0
# 494       536409     21866     UNION JACK FLAG LUGGAGE TAG       1.0
# 517       536409     21866     UNION JACK FLAG LUGGAGE TAG       1.0
# 521       536409     22900  SET 2 TEA TOWELS I LOVE LONDON       1.0
# ...          ...       ...                             ...       ...
# 213360    555537     21900                  KEY FOB , SHED       1.0
# 213377    555537     22149      FELTCRAFT 6 FLOWER FRIENDS       1.0
# 213379    555537     22149      FELTCRAFT 6 FLOWER FRIENDS       1.0
# 213445    555541     22960        JAM MAKING SET WITH JARS       1.0
# 213446    555541     22960        JAM MAKING SET WITH JARS       1.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 485     12/1/2010 11:45       4.95     17908.0  United Kingdom
# ...

# %%
# Identificar quantos valores duplicados há em cada duplicata
(
  df
 .groupby(df.columns.tolist(), dropna=False)
 .size()
 .to_frame('n_duplicates')
 .query('n_duplicates>1')
 .sort_values('n_duplicates', ascending=False)

)
# Out:
#                                                                                                                       n_duplicates
# InvoiceNo StockCode Description                        Quantity InvoiceDate      UnitPrice CustomerID Country
# 555524    22698     PINK REGENCY TEACUP AND SAUCER      1.0     6/5/2011 11:37   2.95      16923.0    United Kingdom            20
#           22697     GREEN REGENCY TEACUP AND SAUCER     1.0     6/5/2011 11:37   2.95      16923.0    United Kingdom            12
# 540524    21756     BATH BUILDING BLOCK WORD            1.0     1/9/2011 12:53   5.95      16735.0    United Kingdom             6
# 538514    21756     BATH BUILDING BLOCK WORD            1.0     12/12/2010 14:27 5.95      15044.0    United Kingdom             6
# 541266    21755     LOVE BUILDING BLOCK WORD            1.0     1/16/2011 16:25  5.95      15673.0    United Kingdom             6
# ...

# %% [markdown]
# # Nova seção

# %%
# Remover valores duplicados
df.drop_duplicates()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 213537    555545     21937              STRAWBERRY   PICNIC BAG       5.0
# 213538    555545     20717               STRAWBERRY SHOPPER BAG      10.0
# 213539    555545    85099F                 JUMBO BAG STRAWBERRY      10.0
# 213540    555545     22383                LUNCH BAG SUKI DESIGN      10.0
# 213541    555545     21931                                  JUM       NaN
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#importando date time
import datetime

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity              float64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
#MUDANDO TYPES COLUNA
df['CustomerID'].isna().sum()
df['CustomerID'].value_counts()
df['CustomerID'] = df['CustomerID'].fillna(0).astype(int)
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity              float64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int64
# Country                object
# dtype: object

# %%
# Box plot com dados "as is"
df.plot.box()
plt.xticks(rotation=60, ha='right')
# Out:
# (array([1, 2, 3]),
#  [Text(1, 0, 'Quantity'), Text(2, 0, 'UnitPrice'), Text(3, 0, 'CustomerID')])

# %%
def is_outlier(array, extreme=False):
  """Custom function to identify outliers in an array"""
  q1,q3 = np.quantile(array, [.25,.75])
  iqr = q3-q1

  factor = 3. if extreme else 1.5
  upper_outlier = q3 + factor*iqr
  lower_outlier = q1 - factor*iqr

  return (array < lower_outlier) | (array > upper_outlier)

# %%
is_outlier(df.UnitPrice)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 213537    False
# 213538    False
# 213539    False
# 213540    False
# 213541    False
# Name: UnitPrice, Length: 213542, dtype: bool

# %%
is_outlier(df.Quantity)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 213537    False
# 213538    False
# 213539    False
# 213540    False
# 213541    False
# Name: Quantity, Length: 213542, dtype: bool

# %%
 df['UnitPrice'].sum()
totalpreco = df['UnitPrice'].sum()
print(totalpreco)
totalquantidade =df ['Quantity'].sum()
print(totalquantidade)
Quantity_PREÇO= totalpreco /totalquantidade
df['Quantity_PREÇO'] =lambda df :Quantity_PREÇO
df[['Quantity_PREÇO']]
print(Quantity_PREÇO)
# Out:
# 1070538.4200000002
# 1989290.0
# 0.5381510086513279

# %%
# Especificando o formato (para dataset grande costuma ser inclusive mais rápido)
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%m/%d/%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213542 entries, 0 to 213541
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       213542 non-null  object
#  1   StockCode       213542 non-null  object
#  2   Description     212703 non-null  object
#  3   Quantity        213541 non-null  float64
#  4   InvoiceDate     213541 non-null  datetime64[ns]
#  5   UnitPrice       213541 non-null  float64
#  6   CustomerID      213542 non-null  int64
#  7   Country         213541 non-null  object
#  8   Quantity_PREÇO  213542 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 14.7+ MB

# %%
 df = df[df['Quantity_PREÇO'].apply(lambda x: isinstance(x, (int, float)))]

# %%
df.dtypes
# Out:
# InvoiceNo                 object
# StockCode                 object
# Description               object
# Quantity                 float64
# InvoiceDate       datetime64[ns]
# UnitPrice                float64
# CustomerID                 int64
# Country                   object
# Quantity_PREÇO            object
# dtype: object

# %%
max_date= df['InvoiceDate'].max()
print(max_date)
# Out:
# NaT

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart-studio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import chart_studio.plotly as py
import cufflinks as cf
import plotly.graph_objects as go
import plotly.express as px

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
px.line(df,x='InvoiceDate',y='UnitPrice')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df,x='Country',y='UnitPrice')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= plt.figure(figsize=(15,10))
plt.bar(df['InvoiceDate'], df['Quantity'], color='green')
plt.ylabel('Vend total por mes')
plt.title('Venda por mes', loc='center', fontsize=18, fontweight='bold', color='black')
# Out:
# Text(0.5, 1.0, 'Venda por mes')

# %%
px.area(df,x='InvoiceDate',y='Country',line_group='Quantity_PREÇO')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cliente_pedido= df.groupby('CustomerID')['InvoiceNo'] .sum()
print(cliente_pedido)
data_totalpreço = df.groupby('InvoiceDate')['Quantity_PREÇO'].sum()
print(data_totalpreço)
df.groupby('CustomerID')
# Out:
# Series([], Name: InvoiceNo, dtype: object)
# Series([], Name: Quantity_PREÇO, dtype: object)
