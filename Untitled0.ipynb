# %% [markdown]
# <a href="https://colab.research.google.com/github/tawanyb/tawanyb/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# primeiro fiz as importacoes abaixo
import seaborn as sns
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import chart_studio.plotly as py
import plotly.express as px
df = pd.read_csv('/content/MKT.csv' ,sep=',')
print(df)
# Out:
#      youtube  facebook  newspaper  sales
# 0      84.72     19.20      48.96  12.60
# 1     351.48     33.96      51.84  25.68
# 2     135.48     20.88      46.32  14.28
# 3     116.64      1.80      36.00  11.52
# 4     318.72     24.00       0.36  20.88
# ..       ...       ...        ...    ...
# 166    45.84      4.44      16.56   9.12
# 167   113.04      5.88       9.72  11.64
# 168   212.40     11.16       7.68  15.36
# 169   340.32     50.40      79.44  30.60
# 170   278.52     10.32      10.44  16.08
#
# [171 rows x 4 columns]

# %% [markdown]
# # Nova seção

# %%
# fiz as informacoes e descricoes pra entender os dados
df.info()

df.describe ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB
#           youtube    facebook   newspaper       sales
# count  171.000000  171.000000  171.000000  171.000000
# mean   178.021053   27.671579   35.240000   16.922807
# std    102.449597   17.913532   24.902918    6.314608
# min      0.840000    0.000000    0.360000    1.920000
# 25%     91.080000   11.700000   13.740000   12.540000
# 50%    179.760000   26.760000   31.080000   15.480000
# 75%    262.980000   43.680000   50.880000   20.820000
# max    355.680000   59.520000  121.080000   32.400000

# %%
df.dtypes
#FIZ DTYPES PRA VERIFICAR OS FORMATOS
# Out:
# youtube      float64
# facebook     float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
#FIZ AS INSTALACOES DOS PACOTES PRA PODER FAZER A CORRELACAO DOS DADOS

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart_studio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# OS GRAFICOS PRA ANALIZAR AS CORRELACOES DOS DADOS

# %%
fig = px.box(df, x='sales')
fig.update_traces(line_color ='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,x_vars=['youtube','facebook','newspaper'], y_vars=['sales'])

# %%
df.corr()
# Out:
#             youtube  facebook  newspaper     sales
# youtube    1.000000  0.086538   0.110759  0.782030
# facebook   0.086538  1.000000   0.293425  0.602918
# newspaper  0.110759  0.293425   1.000000  0.254987
# sales      0.782030  0.602918   0.254987  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df['sales'])
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %% [markdown]
# # **modelo linear regressor**

# %%
X = df [['youtube','facebook','newspaper']]
Y = df [['sales']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train,Y_test = train_test_split( X ,Y, train_size = 0.7, test_size=0.3,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (119, 3)
# (52, 3)
# (119, 1)
# (52, 1)

# %%
from sklearn.linear_model import LinearRegression

ln=LinearRegression()

# %%
ln.fit(X_train,Y_train )
# Out:
# LinearRegression()

# %%
Y_pred = ln.predict (X_test)

# %%
from sklearn.metrics import r2_score

# %%
r = r2_score(Y_test, Y_pred)

# %%
print('r_quadrado:',r)
# Out:
# r_quadrado: 0.882423505618885

# %%
import matplotlib.pyplot as plt

# %%
c = [i for i in range(1, 53, 1)]

fig = plt.figure(figsize=(10, 6))
plt.plot(c, Y_test)
plt.plot(c, Y_pred)
